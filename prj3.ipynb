# %% [markdown]
# Reinforced Ai vs Min max

# %%
import numpy as np
from math import inf as infinity
import itertools
import random
import time

game_state = [[' ',' ',' '],
              [' ',' ',' '],
              [' ',' ',' ']]
players = ['X','O']

def play_move(state, player, block_num):
    if state[int((block_num-1)/3)][(block_num-1)%3] is ' ':
        state[int((block_num-1)/3)][(block_num-1)%3] = player
    else:
        block_num = int(input("Block is not empty, Choose again: "))
        play_move(state, player, block_num)
    
def copy_game_state(state):
    new_state = [[' ',' ',' '],[' ',' ',' '],[' ',' ',' ']]
    for i in range(3):
        for j in range(3):
            new_state[i][j] = state[i][j]
    return new_state
    
def check_current_state(game_state):    
    # Checking horizontals
    if (game_state[0][0] == game_state[0][1] and game_state[0][1] == game_state[0][2] and game_state[0][0] is not ' '):
        return game_state[0][0], "Done"
    if (game_state[1][0] == game_state[1][1] and game_state[1][1] == game_state[1][2] and game_state[1][0] is not ' '):
        return game_state[1][0], "Done"
    if (game_state[2][0] == game_state[2][1] and game_state[2][1] == game_state[2][2] and game_state[2][0] is not ' '):
        return game_state[2][0], "Done"
    
    # Check verticals
    if (game_state[0][0] == game_state[1][0] and game_state[1][0] == game_state[2][0] and game_state[0][0] is not ' '):
        return game_state[0][0], "Done"
    if (game_state[0][1] == game_state[1][1] and game_state[1][1] == game_state[2][1] and game_state[0][1] is not ' '):
        return game_state[0][1], "Done"
    if (game_state[0][2] == game_state[1][2] and game_state[1][2] == game_state[2][2] and game_state[0][2] is not ' '):
        return game_state[0][2], "Done"
    
    # Check diagonals
    if (game_state[0][0] == game_state[1][1] and game_state[1][1] == game_state[2][2] and game_state[0][0] is not ' '):
        return game_state[1][1], "Done"
    if (game_state[2][0] == game_state[1][1] and game_state[1][1] == game_state[0][2] and game_state[2][0] is not ' '):
        return game_state[1][1], "Done"
    
    # if draw then
    draw_flag = 0
    for i in range(3):
        for j in range(3):
            if game_state[i][j] is ' ':
                draw_flag = 1
    if draw_flag is 0:
        return None, "Draw"
    
    return None, "Not Done"

def print_board(game_state):
    print('----------------')
    print('| ' + str(game_state[0][0]) + ' || ' + str(game_state[0][1]) + ' || ' + str(game_state[0][2]) + ' |')
    print('----------------')
    print('| ' + str(game_state[1][0]) + ' || ' + str(game_state[1][1]) + ' || ' + str(game_state[1][2]) + ' |')
    print('----------------')
    print('| ' + str(game_state[2][0]) + ' || ' + str(game_state[2][1]) + ' || ' + str(game_state[2][2]) + ' |')
    print('----------------')
    
  
# Initializiation of state values
player = ['X','O',' ']
states_dict = {}
all_possible_states = [[list(i[0:3]),list(i[3:6]),list(i[6:10])] for i in itertools.product(player, repeat = 9)]
n_states = len(all_possible_states) # 2 players, 9 spaces
n_actions = 9   # 9 spaces
state_values_for_AI_O = np.full((n_states),0.0)
state_values_for_AI_X = np.full((n_states),0.0)
print("n_states = %i \nn_actions = %i"%(n_states, n_actions))

# State values for AI 'O'
for i in range(n_states):
    states_dict[i] = all_possible_states[i]
    winner, _ = check_current_state(states_dict[i])
    if winner == 'O':   # AI won
        state_values_for_AI_O[i] = 1
    elif winner == 'X':   # AI lost
        state_values_for_AI_O[i] = -1
        
# State values for AI 'X'       
for i in range(n_states):
    winner, _ = check_current_state(states_dict[i])
    if winner == 'O':   # AI lost
        state_values_for_AI_X[i] = -1
    elif winner == 'X':   # AI won
        state_values_for_AI_X[i] = 1

def update_state_value_O(curr_state_idx, next_state_idx, learning_rate):
    new_value = state_values_for_AI_O[curr_state_idx] + learning_rate*(state_values_for_AI_O[next_state_idx]  - state_values_for_AI_O[curr_state_idx])
    state_values_for_AI_O[curr_state_idx] = new_value
    
def update_state_value_X(curr_state_idx, next_state_idx, learning_rate):
    new_value = state_values_for_AI_X[curr_state_idx] + learning_rate*(state_values_for_AI_X[next_state_idx]  - state_values_for_AI_X[curr_state_idx])
    state_values_for_AI_X[curr_state_idx] = new_value

def getBestMove(state, player, epsilon):
    '''
    Reinforcement Learning Algorithm
    '''    
    moves = []
    curr_state_values = []
    empty_cells = []
    for i in range(3):
        for j in range(3):
            if state[i][j] is ' ':
                empty_cells.append(i*3 + (j+1))
    
    for empty_cell in empty_cells:
        moves.append(empty_cell)
        new_state = copy_game_state(state)
        play_move(new_state, player, empty_cell)
        next_state_idx = list(states_dict.keys())[list(states_dict.values()).index(new_state)]
        if player == 'X':
            curr_state_values.append(state_values_for_AI_X[next_state_idx])
        else:
            curr_state_values.append(state_values_for_AI_O[next_state_idx])
        
    print('Possible moves = ' + str(moves))
    print('Move values = ' + str(curr_state_values))    
    best_move_idx = np.argmax(curr_state_values)
    
    if np.random.uniform(0,1) <= epsilon:       # Exploration
        best_move = random.choice(empty_cells)
        print('Agent decides to explore! Takes action = ' + str(best_move))
        epsilon *= 0.99
    else:   #Exploitation
        best_move = moves[best_move_idx]
        print('Agent decides to exploit! Takes action = ' + str(best_move))
    return best_move
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:28: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:30: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:32: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:36: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:38: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:40: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:44: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:46: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:53: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:55: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:114: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:28: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:30: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:32: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:36: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:38: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:40: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:44: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:46: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:53: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:55: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:114: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if state[int((block_num-1)/3)][(block_num-1)%3] is ' ':
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:28: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[0][0] == game_state[0][1] and game_state[0][1] == game_state[0][2] and game_state[0][0] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:30: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[1][0] == game_state[1][1] and game_state[1][1] == game_state[1][2] and game_state[1][0] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:32: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[2][0] == game_state[2][1] and game_state[2][1] == game_state[2][2] and game_state[2][0] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:36: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[0][0] == game_state[1][0] and game_state[1][0] == game_state[2][0] and game_state[0][0] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:38: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[0][1] == game_state[1][1] and game_state[1][1] == game_state[2][1] and game_state[0][1] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:40: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[0][2] == game_state[1][2] and game_state[1][2] == game_state[2][2] and game_state[0][2] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:44: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[0][0] == game_state[1][1] and game_state[1][1] == game_state[2][2] and game_state[0][0] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:46: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (game_state[2][0] == game_state[1][1] and game_state[1][1] == game_state[0][2] and game_state[2][0] is not ' '):
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:53: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if game_state[i][j] is ' ':
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:55: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if draw_flag is 0:
# n_states = 19683
# n_actions = 9
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\4158476798.py:114: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if state[i][j] is ' ':

# %%
#LOAD TRAINED STATE VALUES
state_values_for_AI_X = np.loadtxt('trained_state_values_X.txt', dtype=np.float64)
state_values_for_AI_O = np.loadtxt('trained_state_values_O.txt', dtype=np.float64)

learning_rate = 0.2
epsilon = 0.2
num_iterations = 10000
for iteration in range(num_iterations):
    game_state = [[' ',' ',' '],
              [' ',' ',' '],
              [' ',' ',' ']]
    current_state = "Not Done"
    print("\nIteration " + str(iteration) + "!")
    print_board(game_state)
    winner = None
    current_player_idx = random.choice([0,1])
        
    while current_state == "Not Done":
        curr_state_idx = list(states_dict.keys())[list(states_dict.values()).index(game_state)]
        if current_player_idx == 0:     # AI_X's turn
            print("\nAI X's turn!")         
            block_choice = getBestMove(game_state, players[current_player_idx], epsilon)
            play_move(game_state ,players[current_player_idx], block_choice)
            new_state_idx = list(states_dict.keys())[list(states_dict.values()).index(game_state)]
            
        else:       # AI_O's turn
            print("\nAI O's turn!")   
            block_choice = getBestMove(game_state, players[current_player_idx], epsilon)
            play_move(game_state ,players[current_player_idx], block_choice)
            new_state_idx = list(states_dict.keys())[list(states_dict.values()).index(game_state)]
        
        print_board(game_state)
        #print('State value = ' + str(state_values_for_AI[new_state_idx]))
        update_state_value_O(curr_state_idx, new_state_idx, learning_rate)
        update_state_value_X(curr_state_idx, new_state_idx, learning_rate)
        winner, current_state = check_current_state(game_state)
        if winner is not None:
            print(str(winner) + " won!")
        else:
            current_player_idx = (current_player_idx + 1)%2
        
        if current_state is "Draw":
            print("Draw!")
            
        #time.sleep(1)
print('Training Complete!')    

# Save state values for future use
np.savetxt('trained_state_values_X.txt', state_values_for_AI_X, fmt = '%.6f')
np.savetxt('trained_state_values_O.txt', state_values_for_AI_O, fmt = '%.6f')
# Out:
# <>:42: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:42: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Aashay\AppData\Local\Temp\ipykernel_21472\455100234.py:42: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_state is "Draw":
# Iteration 0!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.222223, -0.181765, -0.166762, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.267598, -0.260843, -0.256776, -0.207062, -0.286806, -0.323863]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.173074, 0.142184, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.115225, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.31493, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.882642, -0.017309, -0.982148, -0.686725]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 3, 9]
# Move values = [0.006569, 0.0, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [3, 9]
# Move values = [-0.997582, 0.0]
# Agent decides to explore! Takes action = 3
# ----------------
# | O || X || X |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [9]
# Move values = [1.0]
# Agent decides to exploit! Takes action = 9
# ----------------
# | O || X || X |
# ----------------
# | O || O || X |
# ----------------
# | X || O || O |
# ----------------
# O won!
#
# Iteration 1!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.18783, -0.351205, 0.128549, -0.281303, -0.168599, -0.291471, -0.224762]
# Agent decides to explore! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | X ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 5, 6, 7, 8, 9]
# Move values = [0.004311, 0.00576, 0.030458, 0.260843, 0.0, -0.055946, -0.002583, -0.005806]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# | X || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 7, 8, 9]
# Move values = [-0.111919, -0.390824, -0.377512, -0.430147, -0.402139, -0.543975, -0.420631]
# Agent decides to exploit! Takes action = 1
# ----------------
# | X ||   ||   |
# ----------------
# | X || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [2, 3, 6, 7, 8, 9]
# Move values = [0.119088, -0.075291, -0.082223, 0.095653, -0.070901, -0.218476]
# Agent decides to exploit! Takes action = 2
# ----------------
# | X || O ||   |
# ----------------
# | X || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [3, 6, 7, 8, 9]
# Move values = [-0.2, -0.3344, 1.0, -0.064, -0.2]
# Agent decides to exploit! Takes action = 7
# ----------------
# | X || O ||   |
# ----------------
# | X || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
# X won!
#
# Iteration 2!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.18783, -0.3331326, 0.128549, -0.281303, -0.168599, -0.291471, -0.224762]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8]
# Move values = [0.0, 0.002621, 0.00539, 0.018232, 0.323863, 0.034854, 0.0, -0.006607]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   || X |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8]
# Move values = [-0.548689, -0.447595, -0.438703, -0.420631, -0.346354, -0.457159, -0.415084]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# |   || O || X |
# ----------------
# |   ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 7, 8]
# Move values = [0.167692, 0.06752, 0.38477, -0.36619, 0.088, 0.088]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || O || X |
# ----------------
# |   ||   || X |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 7, 8]
# Move values = [-0.5904, -0.5904, -0.488, -0.506477, -0.488]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   || O |
# ----------------
# | X || O || X |
# ----------------
# |   ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 7, 8]
# Move values = [0.894194, 0.2, 1.0, 0.0]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   || O |
# ----------------
# | X || O || X |
# ----------------
# | O ||   || X |
# ----------------
# O won!
#
# Iteration 3!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.18783, -0.3331326, 0.128549, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.218789, -0.236198, -0.147603, -0.256198, -0.365461, -0.221161, -0.234462, -0.179749]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.03219, 0.041969, -0.02929, 0.135337, -0.0806, -0.029527, -0.016987]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   || O |
# ----------------
# |   || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 7, 8, 9]
# Move values = [-0.751839, -0.702165, -0.037341, -0.787231, -0.861368, -0.801471]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 7, 8, 9]
# Move values = [-0.006103, 0.109279, -0.181381, -0.020392, -0.171731]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 7, 8]
# Move values = [0.401143, -0.2, -0.2, -0.12]
# Agent decides to explore! Takes action = 8
# ----------------
# |   ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   || O || X |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 7]
# Move values = [1.0, -0.104583, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | X ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   || O || X |
# ----------------
# X won!
#
# Iteration 4!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.2191908, -0.181765, -0.166762, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.267598, -0.2310582, -0.256776, -0.1940864, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.173074, 0.1367922, 0.111264, 0.062185, 0.035078]
# Agent decides to explore! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 8, 9]
# Move values = [-0.106114, -0.417, 0.11756, -0.219671, -0.030374, 0.208651]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   || O |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 6, 8]
# Move values = [-0.67232, -0.737856, -0.5904, -0.67232, 0.00537]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   || O |
# ----------------
# |   || O ||   |
# ----------------
# | X || O || X |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6]
# Move values = [-0.67232, -0.004281, -0.207588, -0.36]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# |   || O ||   |
# ----------------
# | X || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6]
# Move values = [0.0, 0.001297, 0.0]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   || X || O |
# ----------------
# | O || O ||   |
# ----------------
# | X || O || X |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 6]
# Move values = [-0.38432, 0.0]
# Agent decides to explore! Takes action = 1
# ----------------
# | X || X || O |
# ----------------
# | O || O ||   |
# ----------------
# | X || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [6]
# Move values = [1.0]
# Agent decides to exploit! Takes action = 6
# ----------------
# | X || X || O |
# ----------------
# | O || O || O |
# ----------------
# | X || O || X |
# ----------------
# O won!
#
# Iteration 5!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.18783, -0.3331326, 0.1323598, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to explore! Takes action = 3
# ----------------
# |   ||   || X |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 5, 6, 7, 8, 9]
# Move values = [0.004713, -0.005492, 0.0, 0.267598, 0.121972, -0.010929, -0.091523, 0.0]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   || X |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 5, 6, 7, 8]
# Move values = [-0.0016, -0.00288, 0.0, 0.070202, 0.0, 0.0, -0.0656]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   || X |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   || O |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 6, 7, 8]
# Move values = [-0.3344, -0.212156, -0.420365, -0.362793, -0.060997, 0.145542]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   || X |
# ----------------
# |   || X ||   |
# ----------------
# |   || O || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7]
# Move values = [-0.544443, -0.533056, -0.488, -0.232, 1.0]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   || X |
# ----------------
# |   || X ||   |
# ----------------
# | X || O || O |
# ----------------
# X won!
#
# Iteration 6!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.21416991999999999, -0.181765, -0.166762, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.267598, -0.2310582, -0.256776, -0.12065432, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.1367922, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.155166, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.2554058, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.882642, -0.015161, -0.982148, -0.686725]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 3, 9]
# Move values = [0.2047716, 0.0, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [3, 9]
# Move values = [-0.9980656, 0.0]
# Agent decides to explore! Takes action = 3
# ----------------
# | O || X || X |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [9]
# Move values = [1.0]
# Agent decides to exploit! Takes action = 9
# ----------------
# | O || X || X |
# ----------------
# | O || O || X |
# ----------------
# | X || O || O |
# ----------------
# O won!
#
# Iteration 7!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.150264, -0.3331326, 0.1323598, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.218789, -0.236198, -0.14514980000000002, -0.256198, -0.365461, -0.221161, -0.234462, -0.179749]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.03219, 0.041969, -0.02929, 0.1157378, -0.0806, -0.029527, -0.016987]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   || O |
# ----------------
# |   || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 7, 8, 9]
# Move values = [-0.751839, -0.702165, 0.004473400000000002, -0.787231, -0.861368, -0.801471]
# Agent decides to explore! Takes action = 4
# ----------------
# |   ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 7, 8, 9]
# Move values = [-0.006103, 0.109279, -0.181381, -0.020392, -0.11338480000000001]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 7, 8, 9]
# Move values = [-0.569609, -0.67232, 0.00427, -0.488]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   || X || O |
# ----------------
# | O || X || X |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 7, 9]
# Move values = [-0.026306, 0.0, -0.104583]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   || X || O |
# ----------------
# | O || X || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 9]
# Move values = [0.0, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X || O |
# ----------------
# | O || X || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [9]
# Move values = [0.0]
# Agent decides to exploit! Takes action = 9
# ----------------
# | O || X || O |
# ----------------
# | O || X || X |
# ----------------
# | X || O || X |
# ----------------
# Draw!
#
# Iteration 8!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.1954668, -0.181765, -0.166762, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.267598, -0.2310582, -0.256776, -0.12388189599999999, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.14046696, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.17521396, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.20735684000000001, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.882642, -0.053083120000000004, -0.982148, -0.686725]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3]
# Move values = [-0.914101, 1.0, 0.002994]
# Agent decides to explore! Takes action = 2
# ----------------
# |   || O ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
# O won!
#
# Iteration 9!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.150264, -0.3331326, 0.1349178, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.218789, -0.236198, -0.1392674, -0.256198, -0.365461, -0.221161, -0.234462, -0.179749]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.03219, 0.041969, -0.02929, 0.09169556, -0.0806, -0.029527, -0.016987]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   || O |
# ----------------
# |   || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 7, 8, 9]
# Move values = [-0.751839, -0.702165, -0.01827708, -0.787231, -0.861368, -0.801471]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 7, 8, 9]
# Move values = [-0.006103, 0.0865692, -0.181381, -0.020392, -0.11338480000000001]
# Agent decides to explore! Takes action = 1
# ----------------
# | X ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [2, 7, 8, 9]
# Move values = [-0.80799, -0.568282, -0.619065, 0.003558]
# Agent decides to exploit! Takes action = 9
# ----------------
# | X ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   || O |
# ----------------
#
# AI X's turn!
# Possible moves = [2, 7, 8]
# Move values = [-0.118361, 0.0, 0.000299]
# Agent decides to exploit! Takes action = 8
# ----------------
# | X ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   || X || O |
# ----------------
#
# AI O's turn!
# Possible moves = [2, 7]
# Move values = [0.0, -0.832228]
# Agent decides to exploit! Takes action = 2
# ----------------
# | X || O || O |
# ----------------
# | O || X || X |
# ----------------
# |   || X || O |
# ----------------
#
# AI X's turn!
# Possible moves = [7]
# Move values = [0.0]
# Agent decides to exploit! Takes action = 7
# ----------------
# | X || O || O |
# ----------------
# | O || X || X |
# ----------------
# | X || X || O |
# ----------------
# Draw!
#
# Iteration 10!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.150264, -0.3331326, 0.13578772, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to explore! Takes action = 3
# ----------------
# |   ||   || X |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 5, 6, 7, 8, 9]
# Move values = [0.004713, -0.005492, 0.0, 0.267598, 0.121972, -0.010929, -0.091523, -0.014040400000000001]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   || X |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.462008, -0.075925, -0.377512, -0.354235, -0.47832, -0.453285, -0.438703]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || X |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7, 8, 9]
# Move values = [0.243782, -0.250986, 0.313405, -0.198485, -0.361071, 0.090799]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   || X || X |
# ----------------
# |   || O || O |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 4, 7, 8, 9]
# Move values = [1.0, -0.351665, -0.488, -0.591383, -0.36]
# Agent decides to exploit! Takes action = 1
# ----------------
# | X || X || X |
# ----------------
# |   || O || O |
# ----------------
# |   ||   ||   |
# ----------------
# X won!
#
# Iteration 11!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.1811498192, -0.181765, -0.166762, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.2292634, -0.2310582, -0.256776, -0.12719890879999998, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.14741636, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.181642536, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.30323047200000003, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.882642, -0.053083120000000004, -0.982148, -0.74938]
# Agent decides to explore! Takes action = 1
# ----------------
# | X ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [2, 3, 9]
# Move values = [1.0, 0.013871, 0.0]
# Agent decides to exploit! Takes action = 2
# ----------------
# | X || O ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
# O won!
#
# Iteration 12!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.17035963712, -0.181765, -0.166762, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.2292634, -0.2310582, -0.256776, -0.13124239903999999, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.1542615952, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.2059601232, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.41911277760000004, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.9061136000000001, -0.053083120000000004, -0.982148, -0.74938]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 3, 9]
# Move values = [0.3634304, 0.0, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [3, 9]
# Move values = [-0.99845248, 0.0]
# Agent decides to exploit! Takes action = 9
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [3]
# Move values = [0.0]
# Agent decides to exploit! Takes action = 3
# ----------------
# | O || X || O |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
# Draw!
#
# Iteration 13!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.16253618950399998, -0.181765, -0.166762, -0.180019, -0.174776]
# Agent decides to explore! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# | O ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 8, 9]
# Move values = [-0.013969, 0.0, 0.010929, 0.055946, 0.221161, 0.0, 0.027185, 0.0]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# | O ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.570428, -0.415214, -0.497934, -0.471813, -0.435655, -0.268858, -0.610805]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# | O || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 9]
# Move values = [0.058404, -0.07566, 0.172061, 0.051528, -0.0144, 0.112668]
# Agent decides to explore! Takes action = 2
# ----------------
# |   || X ||   |
# ----------------
# |   || X ||   |
# ----------------
# | O || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 3, 4, 6, 9]
# Move values = [0.0, -0.225651, 0.0, -0.388491, 1.0]
# Agent decides to exploit! Takes action = 9
# ----------------
# |   || X ||   |
# ----------------
# |   || X ||   |
# ----------------
# | O || O || O |
# ----------------
# O won!
#
# Iteration 14!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.16253618950399998, -0.181765, -0.1776418, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.2292634, -0.2310582, -0.256776, -0.135846238272, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.1646013008, 0.111264, 0.062185, 0.035078]
# Agent decides to explore! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.24859065408000003, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.34590684608, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.9061136000000001, -0.115152576, -0.982148, -0.74938]
# Agent decides to explore! Takes action = 3
# ----------------
# |   ||   || X |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 9]
# Move values = [-0.36, 1.0, 0.0]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || O || X |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
# O won!
#
# Iteration 15!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.17373080000000002, -0.3331326, 0.13578772, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to explore! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | X ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 5, 6, 7, 8, 9]
# Move values = [0.004311, 0.00576, 0.030458, 0.2310582, 0.0, -0.055946, -0.002583, -0.005806]
# Agent decides to explore! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | X ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 5, 6, 7, 9]
# Move values = [-0.02087, 0.0, 0.0, 0.018708, 0.0, 0.0, 0.0]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# | X || X ||   |
# ----------------
# |   || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 6, 7, 9]
# Move values = [-0.697692, -0.36, -0.099401, -0.03712, -0.051528, 0.074113]
# Agent decides to explore! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | X || X || O |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 7, 9]
# Move values = [0.17056, -0.001048, 0.0, 0.0, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | X ||   ||   |
# ----------------
# | X || X || O |
# ----------------
# |   || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [2, 3, 7, 9]
# Move values = [-0.488, 0.070515, -0.337856, 0.04]
# Agent decides to exploit! Takes action = 3
# ----------------
# | X ||   || O |
# ----------------
# | X || X || O |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [2, 7, 9]
# Move values = [-0.577856, 1.0, 1.0]
# Agent decides to explore! Takes action = 9
# ----------------
# | X ||   || O |
# ----------------
# | X || X || O |
# ----------------
# |   || O || X |
# ----------------
# X won!
#
# Iteration 16!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.15719819925759998, -0.181765, -0.1776418, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.2292634, -0.2310582, -0.256776, -0.1415972507776, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.18139917145599999, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.26805389248, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.47315507686400005, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.9061136000000001, -0.115152576, -0.9857184, -0.74938]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 3, 9]
# Move values = [0.29074432, 0.0, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [3, 9]
# Move values = [-0.99845248, 0.0]
# Agent decides to exploit! Takes action = 9
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [3]
# Move values = [0.0]
# Agent decides to explore! Takes action = 3
# ----------------
# | O || X || O |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
# Draw!
#
# Iteration 17!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.15407800956159998, -0.181765, -0.1776418, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.2292634, -0.2310582, -0.256776, -0.14955763491328, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.19873011566079998, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.3090741293568, -0.28189, -0.828893]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X || X ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 6, 9]
# Move values = [-0.488, -0.424717, -0.51232, 1.0, 0.0]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || O |
# ----------------
# | X || X ||   |
# ----------------
# O won!
#
# Iteration 18!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.17373080000000002, -0.26598948, 0.13578772, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.218789, -0.236198, -0.12975303200000002, -0.256198, -0.365461, -0.2307004, -0.234462, -0.179749]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.03219, 0.041969, -0.02929, 0.077011864, -0.0806, -0.029527, -0.016987]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   || O |
# ----------------
# |   || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 7, 8, 9]
# Move values = [-0.751839, -0.702165, -0.013401064, -0.787231, -0.861368, -0.801471]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 7, 8, 9]
# Move values = [-0.005594, 0.0865692, -0.181381, -0.020392, -0.11338480000000001]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# | O || X || X |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 7, 8, 9]
# Move values = [-0.569609, -0.67232, 0.003416, -0.488]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   || X || O |
# ----------------
# | O || X || X |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 7, 9]
# Move values = [-0.026306, 0.0, -0.104583]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   || X || O |
# ----------------
# | O || X || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 9]
# Move values = [0.0, 0.0]
# Agent decides to explore! Takes action = 1
# ----------------
# | O || X || O |
# ----------------
# | O || X || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [9]
# Move values = [0.0]
# Agent decides to explore! Takes action = 9
# ----------------
# | O || X || O |
# ----------------
# | O || X || X |
# ----------------
# | X || O || X |
# ----------------
# Draw!
#
# Iteration 19!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.17373080000000002, -0.26598948, 0.13458078240000002, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.218789, -0.236198, -0.1192047984, -0.256198, -0.365461, -0.2307004, -0.234462, -0.179749]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.03219, 0.041969, -0.02929, 0.064289704, -0.0806, -0.029527, -0.016987]
# Agent decides to explore! Takes action = 7
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 6, 8, 9]
# Move values = [-0.013451, 0.0, 0.00512, 0.1152, -0.004516, 0.109514]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   ||   || O |
# ----------------
# |   || X || O |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 8, 9]
# Move values = [-0.2, -0.09312, -0.36, -0.2, 0.0256]
# Agent decides to exploit! Takes action = 9
# ----------------
# |   ||   || O |
# ----------------
# |   || X || O |
# ----------------
# | X ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 8]
# Move values = [0.04, 0.0, -0.36, -0.2]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O ||   || O |
# ----------------
# |   || X || O |
# ----------------
# | X ||   || X |
# ----------------
#
# AI X's turn!
# Possible moves = [2, 4, 8]
# Move values = [0.0, -0.790285, 1.0]
# Agent decides to exploit! Takes action = 8
# ----------------
# | O ||   || O |
# ----------------
# |   || X || O |
# ----------------
# | X || X || X |
# ----------------
# X won!
#
# Iteration 20!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.196382, -0.266876, -0.077614, -0.242124, 0.153173934631936, -0.181765, -0.1776418, -0.180019, -0.174776]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.250661, -0.388517, -0.2292634, -0.2310582, -0.256776, -0.159392131062784, -0.286806, -0.3283612]
# Agent decides to exploit! Takes action = 7
# ----------------
# |   ||   ||   |
# ----------------
# |   || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 8, 9]
# Move values = [-0.044258, -0.050012, -0.1801894, 0.21536209252863997, 0.111264, 0.062185, 0.035078]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   ||   ||   |
# ----------------
# | O || O ||   |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 6, 8, 9]
# Move values = [-0.749846, -0.838447, -0.946038, -0.3090741293568, -0.425512, -0.828893]
# Agent decides to explore! Takes action = 6
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 8, 9]
# Move values = [-0.650585, 0.058083, -0.02042, 0.40155457669120004, 0.04046]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 9]
# Move values = [-0.9061136000000001, -0.1502709248, -0.9857184, -0.74938]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 3, 9]
# Move values = [0.232595456, 0.0, 0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [3, 9]
# Move values = [-0.99845248, 0.0]
# Agent decides to exploit! Takes action = 9
# ----------------
# | O || X ||   |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [3]
# Move values = [0.0]
# Agent decides to exploit! Takes action = 3
# ----------------
# | O || X || O |
# ----------------
# | O || O || X |
# ----------------
# | X || O || X |
# ----------------
# Draw!
#
# Iteration 21!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.112896, -0.354569, -0.17373080000000002, -0.26598948, 0.1315055856, -0.281303, -0.168599, -0.291471, -0.2445822]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.218789, -0.236198, -0.07924383872, -0.256198, -0.365461, -0.2307004, -0.234462, -0.179749]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.03219, 0.041969, -0.02929, 0.064289704, -0.08752, -0.029527, -0.016987]
# Agent decides to explore! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7, 8, 9]
# ...
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.2188411834368, -0.25274560544, -0.17540976492124036, -0.22975147999999998, -0.32689599999999996, -0.2674842048, -0.27812324153823126, -0.2558968831011226]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.04602784, 0.12213606451687868, -0.0035517999999999973, 0.064289704, -0.0919188, -0.029527, -0.016987]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 4, 6, 7, 8]
# Move values = [0.006264, -0.053161, -0.16, -0.0962768, -0.16, -0.48285491199999997]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   || X |
# ----------------
#
# AI X's turn!
# Possible moves = [2, 4, 6, 7, 8]
# Move values = [0.043816, -0.488, -0.2, -0.737856, -0.2]
# Agent decides to explore! Takes action = 7
# ----------------
# | O ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# | X ||   || X |
# ----------------
#
# AI O's turn!
# Possible moves = [2, 4, 6, 8]
# Move values = [1.0, 0.235621, 0.06559999999999999, 0.2]
# Agent decides to exploit! Takes action = 2
# ----------------
# | O || O || O |
# ----------------
# |   || X ||   |
# ----------------
# | X ||   || X |
# ----------------
# O won!
#
# Iteration 233!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.145312, -0.37063564000000004, -0.18438486984863744, -0.283428797743616, 0.17618391222268964, -0.27599863332181807, -0.21260126500562915, -0.27844759999999996, -0.2554864256]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.2188411834368, -0.25274560544, -0.1369304119369923, -0.22975147999999998, -0.32689599999999996, -0.2674842048, -0.27812324153823126, -0.2558968831011226]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.04602784, 0.12213606451687868, -0.0035517999999999973, 0.064289704, -0.0919188, -0.029527, -0.014842399999999999]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7, 8, 9]
# Move values = [-0.591174, -0.854805504, -0.22799679999999997, -0.77717632, -0.0468722009396499, -0.7448744960000001]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 4, 6, 7, 9]
# Move values = [-0.456479, -0.1765278, -0.004258, -0.055024039999999996, 0.051848205840933574]
# Agent decides to exploit! Takes action = 9
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7]
# Move values = [-0.04019192480961417, -0.27264976, -0.46240000000000003, -0.2]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O || X |
# ----------------
#
# AI X's turn!
# Possible moves = [4, 6, 7]
# Move values = [0.020042659802707814, -0.045369, 0.0]
# Agent decides to exploit! Takes action = 4
# ----------------
# | O || X || O |
# ----------------
# | X || X ||   |
# ----------------
# |   || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [6, 7]
# Move values = [0.0, -0.7902848]
# Agent decides to explore! Takes action = 6
# ----------------
# | O || X || O |
# ----------------
# | X || X || O |
# ----------------
# |   || O || X |
# ----------------
#
# AI X's turn!
# Possible moves = [7]
# Move values = [0.0]
# Agent decides to exploit! Takes action = 7
# ----------------
# | O || X || O |
# ----------------
# | X || X || O |
# ----------------
# | X || O || X |
# ----------------
# Draw!
#
# Iteration 234!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.145312, -0.37063564000000004, -0.18438486984863744, -0.283428797743616, 0.16833321216555017, -0.27599863332181807, -0.21260126500562915, -0.27844759999999996, -0.2554864256]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.2188411834368, -0.25274560544, -0.13397154245296958, -0.22975147999999998, -0.32689599999999996, -0.2674842048, -0.27812324153823126, -0.2558968831011226]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8]
# Move values = [-0.185342, -0.09352, 0.0270532, 0.008793, -0.018294, -0.01858, 0.367642615744512]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   || X || O |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7]
# Move values = [-0.4586856, -0.1880133997056, -0.954079, -0.484203, -0.6299496, -0.784255]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || O ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   || X || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 3, 4, 6, 7]
# Move values = [-0.003088, 0.235737728, -0.049454, 0.08076608, -0.447103]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   || O || X |
# ----------------
# |   || X ||   |
# ----------------
# |   || X || O |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7]
# Move values = [-0.87241, -0.72455, -0.6736552, -0.1312338176]
# Agent decides to explore! Takes action = 7
# ----------------
# |   || O || X |
# ----------------
# |   || X ||   |
# ----------------
# | O || X || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 4, 6]
# Move values = [0.0, 0.003976, 0.133868032]
# Agent decides to exploit! Takes action = 6
# ----------------
# |   || O || X |
# ----------------
# |   || X || X |
# ----------------
# | O || X || O |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4]
# Move values = [-0.964393, 0.0]
# Agent decides to exploit! Takes action = 4
# ----------------
# |   || O || X |
# ----------------
# | O || X || X |
# ----------------
# | O || X || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1]
# Move values = [0.0]
# Agent decides to exploit! Takes action = 1
# ----------------
# | X || O || X |
# ----------------
# | O || X || X |
# ----------------
# | O || X || O |
# ----------------
# Draw!
#
# Iteration 235!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.145312, -0.37063564000000004, -0.18438486984863744, -0.283428797743616, 0.18584594635266466, -0.27599863332181807, -0.21260126500562915, -0.27844759999999996, -0.2554864256]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.2188411834368, -0.25274560544, -0.13397154245296958, -0.22975147999999998, -0.32689599999999996, -0.2674842048, -0.27812324153823126, -0.27824602962980044]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.04602784, 0.10708329180143292, -0.0035517999999999973, 0.064289704, -0.0919188, -0.029527, -0.014842399999999999]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7, 8, 9]
# Move values = [-0.591174, -0.854805504, -0.22799679999999997, -0.77717632, -0.047867401919906634, -0.7448744960000001]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 4, 6, 7, 9]
# Move values = [-0.456479, -0.1765278, -0.004258, -0.055024039999999996, 0.049516949634669696]
# Agent decides to explore! Takes action = 1
# ----------------
# | X || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [4, 6, 7, 9]
# Move values = [-0.307479, -0.689009, -0.1904, 0.663542]
# Agent decides to exploit! Takes action = 9
# ----------------
# | X || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O || O |
# ----------------
#
# AI X's turn!
# Possible moves = [4, 6, 7]
# Move values = [-0.865782, -0.743151, -0.790285]
# Agent decides to exploit! Takes action = 6
# ----------------
# | X || X || O |
# ----------------
# |   || X || X |
# ----------------
# |   || O || O |
# ----------------
#
# AI O's turn!
# Possible moves = [4, 7]
# Move values = [0.03941, 1.0]
# Agent decides to exploit! Takes action = 7
# ----------------
# | X || X || O |
# ----------------
# |   || X || X |
# ----------------
# | O || O || O |
# ----------------
# O won!
#
# Iteration 236!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.145312, -0.37063564000000004, -0.18438486984863744, -0.283428797743616, 0.17547106557272565, -0.27599863332181807, -0.21260126500562915, -0.27844759999999996, -0.2554864256]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.2188411834368, -0.25274560544, -0.12859389232266225, -0.22975147999999998, -0.32689599999999996, -0.2674842048, -0.27812324153823126, -0.27824602962980044]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8]
# Move values = [-0.185342, -0.09352, 0.0270532, 0.008793, -0.018294, -0.01858, 0.3317167725367296]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   || X || O |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7]
# Move values = [-0.4586856, -0.19755826536447998, -0.954079, -0.484203, -0.6299496, -0.784255]
# Agent decides to explore! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || X || O |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7]
# Move values = [-0.488, 1.0, -0.2, 0.0, -0.2]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || X || O |
# ----------------
# X won!
#
# Iteration 237!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.145312, -0.37063564000000004, -0.18438486984863744, -0.283428797743616, 0.1960260583841406, -0.27599863332181807, -0.21260126500562915, -0.27844759999999996, -0.2554864256]
# Agent decides to exploit! Takes action = 5
# ----------------
# |   ||   ||   |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 6, 7, 8, 9]
# Move values = [-0.2188411834368, -0.25274560544, -0.12859389232266225, -0.22975147999999998, -0.32689599999999996, -0.2674842048, -0.27812324153823126, -0.2889401782111863]
# Agent decides to exploit! Takes action = 3
# ----------------
# |   ||   || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 2, 4, 6, 7, 8, 9]
# Move values = [-0.04602784, 0.09524011382512766, -0.0035517999999999973, 0.064289704, -0.0919188, -0.029527, -0.014842399999999999]
# Agent decides to exploit! Takes action = 2
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7, 8, 9]
# Move values = [-0.591174, -0.854805504, -0.22799679999999997, -0.77717632, 0.053001878464074705, -0.7448744960000001]
# Agent decides to exploit! Takes action = 8
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O ||   |
# ----------------
#
# AI X's turn!
# Possible moves = [1, 4, 6, 7, 9]
# Move values = [-0.4978916, -0.1765278, -0.004258, -0.055024039999999996, 0.049516949634669696]
# Agent decides to exploit! Takes action = 9
# ----------------
# |   || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 4, 6, 7]
# Move values = [-0.0361620718082329, -0.27264976, -0.46240000000000003, -0.2]
# Agent decides to exploit! Takes action = 1
# ----------------
# | O || X || O |
# ----------------
# |   || X ||   |
# ----------------
# |   || O || X |
# ----------------
#
# AI X's turn!
# Possible moves = [4, 6, 7]
# Move values = [0.016034127842166252, -0.045369, 0.0]
# Agent decides to exploit! Takes action = 4
# ----------------
# | O || X || O |
# ----------------
# | X || X ||   |
# ----------------
# |   || O || X |
# ----------------
#
# AI O's turn!
# Possible moves = [6, 7]
# Move values = [0.0, -0.7902848]
# Agent decides to exploit! Takes action = 6
# ----------------
# | O || X || O |
# ----------------
# | X || X || O |
# ----------------
# |   || O || X |
# ----------------
#
# AI X's turn!
# Possible moves = [7]
# Move values = [0.0]
# Agent decides to exploit! Takes action = 7
# ----------------
# | O || X || O |
# ----------------
# | X || X || O |
# ----------------
# | X || O || X |
# ----------------
# Draw!
#
# Iteration 238!
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
#
# AI O's turn!
# Possible moves = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Move values = [-0.180692737024, -0.21485159839999998, -0.10634997717297906, -0.256384, 0.19827107571900973, -0.13832692, -0.1989867712, -0.21076463949720867, -0.18850851983960065]
# Agent decides to explore! Takes action = 9
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   ||   |
# ----------------
# |   ||   || O |
# ----------------
#
# AI X's turn!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 22
#      20 if current_player_idx == 0:     # AI_X's turn
#      21     print("\nAI X's turn!")
# ---> 22     block_choice = getBestMove(game_state, players[current_player_idx], epsilon)
#      23     play_move(game_state ,players[current_player_idx], block_choice)
#      24     new_state_idx = list(states_dict.keys())[list(states_dict.values()).index(game_state)]
#
# Cell In[2], line 123, in getBestMove(state, player, epsilon)
#     121 next_state_idx = list(states_dict.keys())[list(states_dict.values()).index(new_state)]
#     122 if player == 'X':
# --> 123     curr_state_values.append(state_values_for_AI_X[next_state_idx])
#     124 else:
#     125     curr_state_values.append(state_values_for_AI_O[next_state_idx])
#
# KeyboardInterrupt:
